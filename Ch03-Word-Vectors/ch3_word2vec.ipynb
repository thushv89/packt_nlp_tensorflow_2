# %% [markdown]
# # Chapter 3: Word2vec - Learning Word Embeddings
#
# ** Warning **:This code can consume a significant amount of memory. If you have significantly large RAM memory (>4GB) you do not need to worry. Otherwise please reduce the `batch_size` or `embedding_size` parameter to allow the model to fit in memory.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
import zipfile
import re
import collections
import numpy as np
import os
import random
import tensorflow as tf
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
import nltk # standard preprocessing
import operator # sorting items in dictionary by value
#nltk.download() #tokenizers/punkt/PY3/english.pickle
import csv

# %% [markdown]
# ## Understanding the data
#
# ### Downloading the data
#
# This code downloads a [BBC dataset](hhttp://mlg.ucd.ie/files/datasets/bbc-fulltext.zip) consisting of news articles published by BBC.

# %%
url = 'http://mlg.ucd.ie/files/datasets/bbc-fulltext.zip'


def download_data(url, data_dir):
    """Download a file if not present, and make sure it's the right size."""
    
    os.makedirs(data_dir, exist_ok=True)

    file_path = os.path.join(data_dir, 'bbc-fulltext.zip')
  
    if not os.path.exists(file_path):
        print('Downloading file...')
        filename, _ = urlretrieve(url, file_path)
    else:
        print("File already exists")
  
    extract_path = os.path.join(data_dir, 'bbc')
    if not os.path.exists(extract_path):
        
        with zipfile.ZipFile(os.path.join(data_dir, 'bbc-fulltext.zip'), 'r') as zipf:
            zipf.extractall(data_dir)
  
    else:
        print("bbc-fulltext.zip has already been extracted")
    
download_data(url, 'data')
# Out:
# File already exists
# bbc-fulltext.zip has already been extracted

# %% [markdown]
# ### Read Data without Preprocessing
# Reads data as it is to a string and tokenize it using spaces and returns a list of words

# %%
def read_data(data_dir):
    
    news_stories = []
    
    print("Reading files")
    
    for root, dirs, files in os.walk(data_dir):
        
        for fi, f in enumerate(files):
            
            if 'README' in f:# or 'entertainment' not in root:
                continue
            
            print("."*fi, f, end='\r')
            with open(os.path.join(root, f), encoding='latin-1') as f:
                
                story = []
                
                for row in f:
                                        
                    story.append(row.strip())
                    
                # If </BODY> tag is encountered, stop capturing
                story = ' '.join(story)                        
                news_stories.append(story)                
                
    print("\nDetected {} stories".format(len(news_stories)))
    return news_stories
                
  
news_stories = read_data(os.path.join('data', 'bbc'))

print('{} words found in the total news set'.format(sum([len(story.split(' ')) for story in news_stories])))
print('Example words (start): ',news_stories[0][:50])
print('Example words (end): ',news_stories[-1][-50:])
# Out:
# Reading files
# ................................................................................................................................................................................................................................................................................................................................................................................................................ 401.txt...................................................................................................... 511.txt56.txt472.txt033.txt
# Detected 2225 stories
# 865163 words found in the total news set
# Example words (start):  Ad sales boost Time Warner profit  Quarterly profi
# Example words (end):  Online was the game, ahhhh them was the days ! LOL

# %% [markdown]
# ### Build a Tokenizer

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer(
    num_words=None,
    filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n',
    lower=True, split=' '
)

tokenizer.fit_on_texts(news_stories)
print("Data fitted on the tokenizer")
# Out:
# Data fitted on the tokenizer

# %% [markdown]
# ### Exploring the tokenizer

# %%
n_vocab = len(tokenizer.word_index.items()) + 1
print("Vocabulary size: {}".format(n_vocab))

print("\nWords at the top")
print('\t', dict(list(tokenizer.word_index.items())[:10]))
print("\nWords at the bottom")
print('\t', dict(list(tokenizer.word_index.items())[-10:]))
# Out:
# Vocabulary size: 32361
#
# Words at the top
# 	 {'the': 1, 'to': 2, 'of': 3, 'and': 4, 'a': 5, 'in': 6, 'for': 7, 'is': 8, 'that': 9, 'on': 10}
#
# Words at the bottom
# 	 {'counsellor': 32351, "'frag'": 32352, 'relasing': 32353, "'real'": 32354, 'hrs': 32355, 'enviroment': 32356, 'trifling': 32357, '24hours': 32358, 'ahhhh': 32359, 'lol': 32360}

# %% [markdown]
# ### Build a Tokenizer (Refined)
#
# Here, we will restrict the vocabulary to 15000 and eleminate words except the first most common 15000 words

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

n_vocab = 15000 + 1
tokenizer = Tokenizer(
    num_words=n_vocab-1,
    filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n',
    lower=True, split=' ', oov_token='',    
)

tokenizer.fit_on_texts(news_stories)
print("Data fitted on the tokenizer")
# Out:
# Data fitted on the tokenizer

# %% [markdown]
# ### Checking the results of the tokenizer

# %%
print("Original: {}".format(news_stories[0][:100]))
print("Sequence IDs: {}".format(tokenizer.texts_to_sequences([news_stories[0][:100]])[0]))
# Out:
# Original: Ad sales boost Time Warner profit  Quarterly profits at US media giant TimeWarner jumped 76% to $1.1
# Sequence IDs: [4223, 187, 716, 66, 3596, 1050, 3938, 626, 21, 49, 303, 717, 8263, 2972, 5321, 3, 108, 108]

# %% [markdown]
# ### Converting all articles to word ID sequences

# %%
news_sequences = tokenizer.texts_to_sequences(news_stories)

# %% [markdown]
# ## Generating skip-grams from the corpus
#
# In TensorFlow you have the convenient `tf.keras.preprocessing.sequence.skipgrams()` function to generate skipgrams.

# %%
sample_word_ids = news_sequences[0][:5]
sample_phrase = ' '.join([tokenizer.index_word[wid] for wid in sample_word_ids])
print("Sample phrase: {}".format(sample_phrase))
print("Sample word IDs: {}\n".format(sample_word_ids))

window_size = 1 # How many words to consider left and right.

inputs, labels = tf.keras.preprocessing.sequence.skipgrams(
    sample_word_ids, 
    vocabulary_size=n_vocab, 
    window_size=window_size, negative_samples=1.0, shuffle=False,
    categorical=False, sampling_table=None, seed=None
)


print("Sample skip-grams")

for inp, lbl in zip(inputs, labels):
    print("\tInput: {} ({}) / Label: {}".format(inp, [tokenizer.index_word[wi] for wi in inp], lbl))
# Out:
# Sample phrase: ad sales boost time warner
# Sample word IDs: [4223, 187, 716, 66, 3596]
#
# Sample skip-grams
# 	Input: [4223, 187] (['ad', 'sales']) / Label: 1
# 	Input: [187, 4223] (['sales', 'ad']) / Label: 1
# 	Input: [187, 716] (['sales', 'boost']) / Label: 1
# 	Input: [716, 187] (['boost', 'sales']) / Label: 1
# 	Input: [716, 66] (['boost', 'time']) / Label: 1
# 	Input: [66, 716] (['time', 'boost']) / Label: 1
# 	Input: [66, 3596] (['time', 'warner']) / Label: 1
# 	Input: [3596, 66] (['warner', 'time']) / Label: 1
# 	Input: [716, 7112] (['boost', 'bounced']) / Label: 0
# 	Input: [187, 13326] (['sales', 'wagoner']) / Label: 0
# 	Input: [3596, 7785] (['warner', 'restored']) / Label: 0
# 	Input: [716, 1676] (['boost', 'connection']) / Label: 0
# 	Input: [187, 8386] (['sales', 'ism']) / Label: 0
# 	Input: [66, 8764] (['time', 'bend']) / Label: 0
# 	Input: [66, 13730] (['time', 'bread']) / Label: 0
# 	Input: [4223, 6966] (['ad', 'radically']) / Label: 0

# %% [markdown]
# ## Generating negative candidates
#
# Word2vec algorithms rely on negative candidates to understand words that *do not* appear in the context of a given target word.

# %%
inputs, labels = tf.keras.preprocessing.sequence.skipgrams(
    sample_word_ids, 
    vocabulary_size=len(tokenizer.word_index.items())+1, 
    window_size=window_size, negative_samples=0, shuffle=False,    
)

inputs, labels = np.array(inputs), np.array(labels)

negative_sampling_candidates, true_expected_count, sampled_expected_count = tf.random.log_uniform_candidate_sampler(
    # A true context word that appears in the context of the target
    true_classes=inputs[:1,1:], # [b, 1] sized tensor
    num_true=1, # number of true words per example
    num_sampled=10,
    unique=True,
    range_max=n_vocab,            
    name="negative_sampling"
)

print("Positive sample: {}".format(inputs[:1,1:]))
print("Negative samples: {}".format(negative_sampling_candidates))
print("true_expected_count: {}".format(true_expected_count))
print("sampled_expected_count: {}".format(sampled_expected_count))
# Out:
# Positive sample: [[187]]
# Negative samples: [   1   10 9744 3062  139    5   14   78 1402  115]
# true_expected_count: [[0.00660027]]
# sampled_expected_count: [4.0367463e-01 1.0333969e-01 1.2804421e-04 4.0727769e-04 8.8460185e-03
#  1.7628242e-01 7.7631921e-02 1.5584969e-02 8.8879210e-04 1.0659459e-02]

# %% [markdown]
# ### Using `tf.nn.sampled_softmax_loss()`

# %%
sampling_table = tf.keras.preprocessing.sequence.make_sampling_table(n_vocab, sampling_factor=1e-05)

print(sampling_table)
# Out:
# [0.00315225 0.00315225 0.00547597 ... 1.         1.         1.        ]

# %% [markdown]
# ### Generating data (positive + negative candidates)

# %%
def skip_gram_data_generator(sequences, window_size, batch_size, negative_samples, vocab_size, seed=None):
    
    rand_sequence_ids = np.arange(len(sequences))                    
    np.random.shuffle(rand_sequence_ids)


    for si in rand_sequence_ids:
        
        positive_skip_grams, _ = tf.keras.preprocessing.sequence.skipgrams(
            sequences[si], 
            vocabulary_size=vocab_size, 
            window_size=window_size, 
            negative_samples=0.0, 
            shuffle=False,
            sampling_table=sampling_table,
            seed=seed
        )
        
        targets, contexts, labels = [], [], []
        
        for target_word, context_word in positive_skip_grams:
            context_class = tf.expand_dims(tf.constant([context_word], dtype="int64"), 1)
            
            negative_sampling_candidates, _, _ = tf.random.log_uniform_candidate_sampler(
              true_classes=context_class,
              num_true=1,
              num_sampled=negative_samples,
              unique=True,
              range_max=vocab_size,              
              name="negative_sampling")

            # Build context and label vectors (for one target word)
            context = tf.concat(
                [tf.constant([context_word], dtype='int64'), negative_sampling_candidates],
                axis=0
            )
            
            label = tf.constant([1] + [0]*negative_samples, dtype="int64")

            # Append each element from the training example to global lists.
            targets.extend([target_word]*(negative_samples+1))
            contexts.append(context)
            labels.append(label)

        contexts, targets, labels = np.concatenate(contexts), np.array(targets), np.concatenate(labels)

        # If seed is not provided generate a random one
        if not seed:
            seed = random.randint(0, 10e6)
            
        np.random.seed(seed)
        np.random.shuffle(contexts)
        np.random.seed(seed)
        np.random.shuffle(targets)
        np.random.seed(seed)
        np.random.shuffle(labels)
        
    
        for eg_id_start in range(0, contexts.shape[0], batch_size):            
            yield (
                targets[eg_id_start: min(eg_id_start+batch_size, inputs.shape[0])], 
                contexts[eg_id_start: min(eg_id_start+batch_size, inputs.shape[0])]
            ), labels[eg_id_start: min(eg_id_start+batch_size, inputs.shape[0])]


news_skip_gram_gen = skip_gram_data_generator(
    news_sequences, 4, 10, 5, n_vocab
)

for btc, bl in news_skip_gram_gen:
    
    print(btc)
    print(bl)
    
    break
# Out:
# (3132,)
# (3132,)
# (3132,)
# (array([ 1368,  5700,  3980,  3323,  3613,     2,  2913, 13396]), array([ 510, 1634,   12,   13,   44,    1,   86,  142], dtype=int64))
# [0 0 0 0 0 1 0 0]

# %% [markdown]
# ## Skip-Gram Algorithm

# %% [markdown]
# ### Defining Hyperparameters
#
# Here we define several hyperparameters including `batch_size` (amount of samples in a single batch) `embedding_size` (size of embedding vectors) `window_size` (context window size).

# %%
batch_size = 4096 # Data points in a single batch

embedding_size = 128 # Dimension of the embedding vector.

window_size=1 # We use a window size of 1 on either side of target word
negative_samples = 4 # Number of negative samples generated per example

epochs = 5 # Number of epochs to train for

# We pick a random validation set to sample nearest neighbors
valid_size = 16 # Random set of words to evaluate similarity on.
# We sample valid datapoints randomly from a large window without always being deterministic
valid_window = 250

# When selecting valid examples, we select some of the most frequent words as well as
# some moderately rare words as well
np.random.seed(54321)
random.seed(54321)

valid_term_ids = np.array(random.sample(range(valid_window), valid_size))
valid_term_ids = np.append(
    valid_term_ids, random.sample(range(1000, 1000+valid_window), valid_size),
    axis=0
)

# %% [markdown]
# ### Defining the Model
#
# Here we will define the skip-gram model. It contains two embedding layers; context and target embeddings. The final output is computed as the dot product between the corresponding lookups from the context and target embeddings for a given batch of context and target words.

# %%
import tensorflow.keras.backend as K

K.clear_session()

# Inputs - skipgrams() function outputs target, context in that order
# we will use the same order
input_1 = tf.keras.layers.Input(shape=(), name='target')
input_2 = tf.keras.layers.Input(shape=(), name='context')

# Two embeddings layers are used one for the context and one for the target
context_embedding_layer = tf.keras.layers.Embedding(
    input_dim=n_vocab, output_dim=embedding_size, name='context_embedding'
)
target_embedding_layer = tf.keras.layers.Embedding(
    input_dim=n_vocab, output_dim=embedding_size, name='target_embedding'
)

# Lookup outputs of the embedding layers
target_out = target_embedding_layer(input_1)
context_out = context_embedding_layer(input_2)

# Computing the dot product between the two 
out = tf.keras.layers.Dot(axes=-1)([context_out, target_out])

# Defining the model
skip_gram_model = tf.keras.models.Model(inputs=[input_1, input_2], outputs=out, name='skip_gram_model')

# Compiling the model
skip_gram_model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True), optimizer='adam', metrics=['accuracy'])

skip_gram_model.summary()
# Out:
# Model: "skip_gram_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# context (InputLayer)            [(None,)]            0
# __________________________________________________________________________________________________
# target (InputLayer)             [(None,)]            0
# __________________________________________________________________________________________________
# context_embedding (Embedding)   (None, 128)          1920128     context[0][0]
# __________________________________________________________________________________________________
# target_embedding (Embedding)    (None, 128)          1920128     target[0][0]
# __________________________________________________________________________________________________
# dot (Dot)                       (None, 1)            0           context_embedding[0][0]
#                                                                  target_embedding[0][0]
# ==================================================================================================
# Total params: 3,840,256
# Trainable params: 3,840,256
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Calculating Word Similarities
#
# We calculate the similarity between two given words in terms of the cosine distance. To do this efficiently we use matrix operations to do so, as shown below. Furthermore, we define the computations as a callback, which will automatically run at the end of an epoch during model training.

# %%
class ValidationCallback(tf.keras.callbacks.Callback):
    
    def __init__(self, valid_term_ids, model_with_embeddings, tokenizer):
        
        self.valid_term_ids = valid_term_ids
        self.model_with_embeddings = model_with_embeddings
        self.tokenizer = tokenizer
        
        super().__init__()
        
    def on_epoch_end(self, epoch, logs=None):
        """ Validation logic """
                
        # We will use context embeddings to get the most similar words
        # Other strategies include: using target embeddings, mean embeddings after avaraging context/target
        embedding_weights = self.model_with_embeddings.get_layer("context_embedding").get_weights()[0]
        normalized_embeddings = embedding_weights / np.sqrt(np.sum(embedding_weights**2, axis=1, keepdims=True))
        
        # Get the embeddings corresponding to valid_term_ids
        valid_embeddings = normalized_embeddings[self.valid_term_ids, :]
        
        # Compute the similarity between valid_term_ids and all the embeddings
        # V x d (d x D) => V x D
        top_k = 5 # Top k items will be displayed
        similarity = np.dot(valid_embeddings, normalized_embeddings.T)
        
        # Invert similarity matrix to negative
        # Ignore the first one because that would be the same word as the probe word
        similarity_top_k = np.argsort(-similarity, axis=1)[:, 1: top_k+1]
                
        # Print the output
        for i, term_id in enumerate(valid_term_ids):
            
            similar_word_str = ', '.join([self.tokenizer.index_word[j] for j in similarity_top_k[i, :] if j > 1])
            print("{}: {}".format(self.tokenizer.index_word[term_id], similar_word_str))
        
        print('\n')

# %% [markdown]
# ### Running the Skip-Gram Algorithm

# %%
skipgram_validation_callback = ValidationCallback(valid_term_ids, skip_gram_model, tokenizer)

for ei in range(epochs):
    
    print("Epoch: {}/{} started".format(ei+1, epochs))
    
    news_skip_gram_gen = skip_gram_data_generator(
        news_sequences, window_size, batch_size, negative_samples, n_vocab
    )
    
    skip_gram_model.fit(
        news_skip_gram_gen, epochs=1, 
        callbacks=skipgram_validation_callback,        
    )

    
os.makedirs('skipgram_embeddings', exist_ok=True)

np.save(
    os.path.join("skipgram_embeddings", "context_embeddings.npy"), 
    skip_gram_model.get_layer("context_embedding").get_weights()[0]
)
np.save(
    os.path.join("skipgram_embeddings", "target_embeddings.npy"), 
    skip_gram_model.get_layer("target_embedding").get_weights()[0]
)
# Out:
# Epoch: 1/5 ended
# 2233/2233 [==============================] - 146s 65ms/step - loss: 0.6845 - accuracy: 0.7998
# election: people, said, start
# months: all, one, also
# with: is, called, about
# you: would, those, not
# were: them, is, made, about
# win: one, what, said, is
# those: said, you, would
# music: is, it, would
# also: one, it, what
# around: date, can, said, not, would
# best: get, do, as
# him: get, them, people
# too: is, music, still
# into: people, other, said, heavy
# through: said, that, uk
# mr: said, game, that
# leave: get, you, do
# 5bn: said, being, would, just
# met: licences, resourced, younger, 'cutting, toughest
# believed: we, 2003, so, has, other
# debut: panel, believe, would, improvement, forsyth
# images: staff, all, they, of
# sound: year, scene, he, produce, 2004
# champions: premier, california, offsetting, bragging, 575
# individual: must, wilkin, hoisted, keira, joe
# businesses: data, party, countries, take
# deutsche: health, becky, globes, rob, when
# especially: indepen, restoration, herren, starts, smartphones
# machine: leave, at, called, more, says
# files: made, years, half, users
# positive: you, one, lead, what, would
# pop: assist, move, its, did, international
#
#
# Epoch: 2/5 ended
# 2233/2233 [==============================] - 145s 65ms/step - loss: 0.5729 - accuracy: 0.7979
# election: next, 23, britain, campaign
# months: many, run, vodafone, made
# with: silk, had, won, form
# you: speak, due, those, believe
# were: made, much, net, expected
# win: due, believe, made, gadgets
# those: due, party, do, take
# music: due, way, get, game
# also: date, made, there, given
# around: date, break, believe, make, done
# best: get, do, way, give
# him: going, party, made, manufacturers'
# too: game, forced, now, added
# into: made, lot, party, lost
# through: information, due, increased, get
# mr: there, bbc, practical, bit
# leave: run, think, make, know
# 5bn: odd, run, everywhere, know, industries
# met: uk, illegal, perpignan, attending, history
# believed: then, missed, cash, threat, wasn't
# debut: money, academy, run, forced, raise
# images: because, like, praised, game, play
# sound: end, cash, see, make
# champions: published, premier, zeppelin, jackson, danielli
# individual: pain, missing, won, instead, sans
# businesses: made, too, drunk, party, challenge
# deutsche: whedon, rob, venezuela's, ferry, humorous
# especially: 2003's, restoration, action, bloggers, ashley
# machine: middle, girl, help, want
# files: boeing, shed, 36, made, expected
# positive: mood, interviewed, should, lead, amro's
# pop: ideals, temko, reheated, lahore, thunderous
#
#
# Epoch: 3/5 ended
# 2233/2233 [==============================] - 145s 65ms/step - loss: 0.5284 - accuracy: 0.8017
# election: iraq, next, campaign, ewoks
# months: weeks, tri, investigate, otherwise, address
# with: seller, gelete, eventual, fight, had
# you: something, done, superb, 2007
# were: umaga, beginning, akin, abortion, claiming
# win: hain, heavy, gadgets, developed
# those: collect, fierce, developed, fire
# music: way, chance, nintendo's, seek
# also: listed, missing, undermine, there
# around: done, al, signing, want
# best: swapped, replay, qualities, developed
# him: therefore, field, signing, interested, preferred
# too: forced, upon, result, heaped, replay
# into: heavy, countryside, couple, lot, pass
# through: surveys, heavy, collect, 645, edu
# mr: limiting, volunteer, loan, blur, sectarianism
# leave: determination, group's, boxes, way
# 5bn: drafted, accession, commercialising, 280, pay
# met: bolz, encouraged, believe, speak, 76
# believed: lack, funny, address, sentence
# debut: estimate, stake, silk, forced, deploying
# images: verdecchia, lick, terrified, catastrophically, rebrand
# sound: mann, unlikely, gadgets, end
# champions: published, debut, danny, broadcast, shortlist
# individual: offices, ariadne, 3d, mcmanus, approves
# businesses: cycle, john's, communicate, heaped, silk
# deutsche: impetuosity, giggs', ferry, ripmobile, drawings
# especially: restoration, desire, judgement, ashley, serve
# machine: embrace, link, 1891, aton, antibiotics
# files: movement, citizens, 1979, make, available
# positive: ringtones, occasion, backbenchers, proud, arrangement
# pop: washed, yes, enter, extras, monitor
#
#
# Epoch: 4/5 ended
# 2233/2233 [==============================] - 146s 65ms/step - loss: 0.5006 - accuracy: 0.8055
# election: conducive, ewoks, atlantic, accidental, board
# months: meaning, tri, options, otherwise, respect
# with: remaining, about, seller, canvass, crass
# you: something, preferred, arrangement, roma, 2007
# were: claiming, delivery, debating, assemblies, umaga
# win: hain, allowed, countryside, gadgets
# those: risk, max, collect, affects, resolutions
# music: christ, floated, sharpness, react, 2015
# also: carrow, prentis, amusing, reservations, refusing
# around: thrilling, tottenham, pupils, funding, scholes
# best: board, replay, protect, angry
# him: preferred, ryan, acclimate, bjorn, pit
# too: heaped, exorcist, euthanasia, conspiracy, improves
# into: repackaging, tav, hockney, conversions, detaining
# through: emergence, frowned, monitoring, unfairness, legacy
# mr: article, said, resignation, limiting, disapproval
# leave: agreeing, uwb, likely, determination, aim
# 5bn: toshack, sharpness, runs, dongwon, lenders
# met: measured, citizens, angels, maximum, tradition
# believed: write, lack, corner, enter, sweeney
# debut: deploying, estimate, forsyth, careful, runway
# images: ball, continue, options, us', freeze
# sound: mann, endured, internment, gadgets
# champions: premier, published, transferred, download, dominique
# individual: somewhat, sans, contribute, baftas, applications
# businesses: mate, 2002's, future, annul, yellow
# deutsche: drawings, giggs', camus, ripmobile, ferry
# especially: necessary, prominence, rot, collar, word
# machine: embrace, respond, courses, aton, accept
# files: flourish, citizens, agreeing, instance, suppliers
# positive: proposal, remedy, electorate, internment, hampered
# pop: qualifications, planemaker, retailer, 'me', nationwide
#
#
# Epoch: 5/5 ended
# 2233/2233 [==============================] - 146s 65ms/step - loss: 0.4842 - accuracy: 0.8056
# election: dinkier, operation, icstis, obtaining, acknowledged
# months: days, weeks, years, detained, meaning
# with: actively, 24th, slamdance, â£258, lacks
# you: something, slovakia's, neighbouring, centres, celebrations
# were: are, was, now, davidson, widened
# win: roaming, coverage, asher, generated, allowed
# those: risk, intentional, thursday, directed, result
# music: disputed, christ, sharpness, floated, removing
# also: prentis, enforcement, carrow, ea, o'gara
# around: pupils, scholes, primus, tottenham, kursk
# best: 1441, trafficking, rushed, cfca, em
# him: me, gevaert, celebrations, acclimate, opponent's
# too: checks, â£78, prophesy, lone, exorcist
# into: adds, tav, copy, owners, hails
# through: clearstream, indicative, beeps, promotion, legacy
# mr: resignation, scott, tony, stead, article
# leave: intelligent, inspire, suspect, literacy, hamlets
# 5bn: christians, 800, crawford, sexagenarian, 'ahead
# met: measured, legacy, server, encouraged, casalme
# believed: seems, declining, forced, hands, lack
# debut: deploying, forsyth, unawares, chapter, entering
# images: fernsehen, immune, supposed, ball, asante
# sound: endured, hang, mortal, mann, offerings
# champions: premier, pottage, kampala, danielli, dominique
# individual: somewhat, contribute, filed, baftas, rebuilding
# businesses: medium, port, 2002's, tackling, doug
# deutsche: drawings, giggs', camus, 102, captain's
# especially: rot, collar, word, rebrand, hasn't
# machine: embrace, painted, sponsored, attend, opec's
# files: agreeing, instance, kuznetsova, fail, flourish
# positive: electorate, proposal, bolz, visitors', strengthen
# pop: 'me', style, lacks, tourism, tuesdays

# %% [markdown]
# ## CBOW Algorithm

# %%
def cbow_grams(sequence, vocabulary_size,
              window_size=4, negative_samples=1., shuffle=True,
              categorical=False, sampling_table=None, seed=None):
    
    targets, contexts, labels = [], [], []    
        
    for i, wi in enumerate(sequence):
        
        
        if not wi or i < window_size or i + 1 > len(sequence)-window_size:
            continue
        if sampling_table is not None:
            if sampling_table[wi] < random.random():
                continue

        window_start = max(0, i - window_size)
        window_end = min(len(sequence), i + window_size + 1)
        
        context_words = [wj for j, wj in enumerate(sequence[window_start:window_end]) if j+window_start != i]
        target_word = wi        
            
        context_classes = tf.expand_dims(tf.constant(context_words, dtype="int64"), 0)

        negative_sampling_candidates, _, _ = tf.random.log_uniform_candidate_sampler(
          true_classes=context_classes,
          num_true=window_size * 2,
          num_sampled=negative_samples,
          unique=True,
          range_max=vocab_size,              
          name="negative_sampling")

        # Build context and label vectors (for one target word)        
        negative_targets = negative_sampling_candidates.numpy().tolist()        

        target = [target_word] + negative_targets
        label = [1] + [0]*negative_samples

        # Append each element from the training example to global lists.
        targets.extend(target)
        contexts.extend([context_words]*(negative_samples+1))
        labels.extend(label)
        
    couples = list(zip(targets, contexts))
    
    seed = random.randint(0, 10e6)
    random.seed(seed)
    random.shuffle(couples)    
    random.seed(seed)
    random.shuffle(labels)
           
    
    return couples, labels


window_size = 1 # How many words to consider left and right.


inputs, labels = cbow_grams(
    tokenizer.texts_to_sequences(["I am going to the store"])[0], 
    vocabulary_size=len(tokenizer.word_index.items())+1, 
    window_size=window_size, negative_samples=4, shuffle=False,
    categorical=False, sampling_table=None, seed=None
)

i = 0
for inp, lbl in zip(inputs, labels):
    i += 1
    print("Input: {} ({})/ Label: {}".format(
        inp, [[tokenizer.index_word[wi] for wi in inp[1]]] + [tokenizer.index_word[inp[0]]], lbl
        )
    )
    # 
    if i >= 20:
        break
# Out:
# (1, 2)
# (1, 2)
# (1, 2)
# (1, 2)
# Input: (3, [132, 2]) ([['going', 'the'], 'to'])/ Label: 1
# Input: (1, [132, 2]) ([['going', 'the'], ''])/ Label: 0
# Input: (985, [3, 1505]) ([['to', 'store'], 'andy'])/ Label: 0
# Input: (428, [28, 132]) ([['i', 'going'], 'am'])/ Label: 1
# Input: (19, [132, 2]) ([['going', 'the'], 'has'])/ Label: 0
# Input: (132, [428, 3]) ([['am', 'to'], 'going'])/ Label: 1
# Input: (2, [3, 1505]) ([['to', 'store'], 'the'])/ Label: 1
# Input: (2010, [428, 3]) ([['am', 'to'], 'opened'])/ Label: 0
# Input: (221, [3, 1505]) ([['to', 'store'], 'record'])/ Label: 0
# Input: (4, [132, 2]) ([['going', 'the'], 'of'])/ Label: 0
# Input: (2172, [428, 3]) ([['am', 'to'], 'brother'])/ Label: 0
# Input: (10, [28, 132]) ([['i', 'going'], 'that'])/ Label: 0
# Input: (35, [132, 2]) ([['going', 'the'], 'which'])/ Label: 0
# Input: (4362, [428, 3]) ([['am', 'to'], 'skype'])/ Label: 0
# Input: (703, [28, 132]) ([['i', 'going'], 'fall'])/ Label: 0
# Input: (1183, [28, 132]) ([['i', 'going'], 'asylum'])/ Label: 0
# Input: (1080, [428, 3]) ([['am', 'to'], 'ray'])/ Label: 0
# Input: (187, [3, 1505]) ([['to', 'store'], 'sales'])/ Label: 0
# Input: (1691, [28, 132]) ([['i', 'going'], 'fighting'])/ Label: 0
# Input: (804, [3, 1505]) ([['to', 'store'], 'either'])/ Label: 0

# %%
window_size = 1 # How many words to consider left and right.

inputs, labels = tf.keras.preprocessing.sequence.skipgrams(
    tokenizer.texts_to_sequences([news_stories[0][:150]])[0], 
    vocabulary_size=len(tokenizer.word_index.items())+1, 
    window_size=window_size, negative_samples=4, shuffle=False,
    categorical=False, sampling_table=None, seed=None
)

i = 0
for inp, lbl in zip(inputs, labels):
    i += 1
    print("Input: {} ({}) / Label: {}".format(inp, [tokenizer.index_word[wi] for wi in inp], lbl))
# Out:
# Input: [912, 3489] (['windows', 'worm']) / Label: 1
# Input: [3489, 912] (['worm', 'windows']) / Label: 1
# Input: [3489, 6614] (['worm', 'travels']) / Label: 1
# Input: [6614, 3489] (['travels', 'worm']) / Label: 1
# Input: [6614, 17] (['travels', 'with']) / Label: 1
# Input: [17, 6614] (['with', 'travels']) / Label: 1
# Input: [17, 9961] (['with', 'tetris']) / Label: 1
# Input: [9961, 17] (['tetris', 'with']) / Label: 1
# Input: [9961, 231] (['tetris', 'users']) / Label: 1
# Input: [231, 9961] (['users', 'tetris']) / Label: 1
# Input: [231, 25] (['users', 'are']) / Label: 1
# Input: [25, 231] (['are', 'users']) / Label: 1
# Input: [25, 87] (['are', 'being']) / Label: 1
# Input: [87, 25] (['being', 'are']) / Label: 1
# Input: [87, 528] (['being', 'warned']) / Label: 1
# Input: [528, 87] (['warned', 'being']) / Label: 1
# Input: [528, 51] (['warned', 'about']) / Label: 1
# Input: [51, 528] (['about', 'warned']) / Label: 1
# Input: [51, 6] (['about', 'a']) / Label: 1
# Input: [6, 51] (['a', 'about']) / Label: 1
# Input: [6, 912] (['a', 'windows']) / Label: 1
# Input: [912, 6] (['windows', 'a']) / Label: 1
# Input: [912, 661] (['windows', 'virus']) / Label: 1
# Input: [661, 912] (['virus', 'windows']) / Label: 1
# Input: [661, 10] (['virus', 'that']) / Label: 1
# Input: [10, 661] (['that', 'virus']) / Label: 1
# Input: [10, 9962] (['that', 'poses']) / Label: 1
# Input: [9962, 10] (['poses', 'that']) / Label: 1
# Input: [9962, 18] (['poses', 'as']) / Label: 1
# Input: [18, 9962] (['as', 'poses']) / Label: 1
# Input: [18, 2] (['as', 'the']) / Label: 1
# Input: [2, 18] (['the', 'as']) / Label: 1
# Input: [2, 2090] (['the', 'hugely']) / Label: 1
# Input: [2090, 2] (['hugely', 'the']) / Label: 1
# Input: [2090, 636] (['hugely', 'popular']) / Label: 1
# Input: [636, 2090] (['popular', 'hugely']) / Label: 1
# Input: [636, 9961] (['popular', 'tetris']) / Label: 1
# Input: [9961, 636] (['tetris', 'popular']) / Label: 1
# Input: [9961, 97] (['tetris', 'game']) / Label: 1
# Input: [97, 9961] (['game', 'tetris']) / Label: 1
# Input: [97, 2] (['game', 'the']) / Label: 1
# Input: [2, 97] (['the', 'game']) / Label: 1
# Input: [2, 9963] (['the', 'cellery']) / Label: 1
# Input: [9963, 2] (['cellery', 'the']) / Label: 1
# Input: [9963, 3489] (['cellery', 'worm']) / Label: 1
# Input: [3489, 9963] (['worm', 'cellery']) / Label: 1
# Input: [3489, 4729] (['worm', 'install']) / Label: 1
# Input: [4729, 3489] (['install', 'worm']) / Label: 1
# Input: [51, 23651] (['about', "presenter's"]) / Label: 0
# Input: [87, 7817] (['being', 'sina']) / Label: 0
# Input: [97, 20851] (['game', "class'"]) / Label: 0
# Input: [18, 20872] (['as', 'buildyourown']) / Label: 0
# Input: [2090, 3946] (['hugely', 'launches']) / Label: 0
# Input: [9961, 28777] (['tetris', '874m']) / Label: 0
# Input: [3489, 30447] (['worm', 'aggressors']) / Label: 0
# Input: [6, 9034] (['a', 'struggles']) / Label: 0
# Input: [2, 7713] (['the', 'strains']) / Label: 0
# Input: [2090, 26812] (['hugely', 'inference']) / Label: 0
# Input: [87, 22690] (['being', 'bihari']) / Label: 0
# Input: [3489, 11005] (['worm', 'banker']) / Label: 0
# Input: [6614, 28888] (['travels', 'satifex']) / Label: 0
# Input: [2, 17838] (['the', 'meteor']) / Label: 0
# Input: [10, 11270] (['that', 'gigantic']) / Label: 0
# Input: [231, 22290] (['users', 'rinaldini']) / Label: 0
# Input: [25, 8057] (['are', 'counting']) / Label: 0
# Input: [17, 27948] (['with', 'unclogging']) / Label: 0
# Input: [9962, 17806] (['poses', 'rea']) / Label: 0
# Input: [6, 16312] (['a', 'discriminating']) / Label: 0
# Input: [10, 5985] (['that', 'phase']) / Label: 0
# Input: [25, 6561] (['are', 'expenditure']) / Label: 0
# Input: [4729, 21863] (['install', 'dorries']) / Label: 0
# Input: [912, 30713] (['windows', 'rehearse']) / Label: 0
# Input: [9962, 20568] (['poses', 'pacquette']) / Label: 0
# Input: [528, 14732] (['warned', 'inmates']) / Label: 0
# Input: [17, 11549] (['with', 'persist']) / Label: 0
# Input: [9961, 10920] (['tetris', 'hampered']) / Label: 0
# Input: [661, 8784] (['virus', 'challenger']) / Label: 0
# Input: [2, 31603] (['the', 'vakacegu']) / Label: 0
# Input: [9963, 20014] (['cellery', 'selections']) / Label: 0
# Input: [97, 11735] (['game', 'nhtcu']) / Label: 0
# Input: [51, 19316] (['about', 'tripoli']) / Label: 0
# Input: [661, 11298] (['virus', 'handlers']) / Label: 0
# Input: [9961, 16849] (['tetris', 'forewarning']) / Label: 0
# Input: [2, 882] (['the', 'outside']) / Label: 0
# Input: [912, 20595] (['windows', 'scouring']) / Label: 0
# Input: [231, 21288] (['users', 'ambience']) / Label: 0
# Input: [636, 8408] (['popular', 'essentials']) / Label: 0
# Input: [636, 728] (['popular', 'round']) / Label: 0
# Input: [528, 30878] (['warned', "shanklin's"]) / Label: 0
# Input: [3489, 28103] (['worm', 'roukis']) / Label: 0
# Input: [18, 18662] (['as', 'renegotiation']) / Label: 0
# Input: [9961, 27869] (['tetris', "barclays'"]) / Label: 0
# Input: [3489, 24011] (['worm', 'punctuate']) / Label: 0
# Input: [6614, 26137] (['travels', 'nant']) / Label: 0
# Input: [9963, 28463] (['cellery', "'urban"]) / Label: 0
# Input: [912, 20668] (['windows', 'oddjob']) / Label: 0
# Input: [51, 8549] (['about', 'tackles']) / Label: 0
# Input: [87, 2297] (['being', 'blamed']) / Label: 0
# Input: [97, 25733] (['game', 'redvers']) / Label: 0
# Input: [18, 3893] (['as', 'metal']) / Label: 0
# Input: [2090, 8937] (['hugely', 'rossignol']) / Label: 0
# Input: [9961, 14451] (['tetris', 'confession']) / Label: 0
# Input: [3489, 26919] (['worm', 'elwa']) / Label: 0
# Input: [6, 4649] (['a', 'withdrawal']) / Label: 0
# Input: [2, 32265] (['the', '9km']) / Label: 0
# Input: [2090, 12702] (['hugely', 'dented']) / Label: 0
# Input: [87, 17432] (['being', 'wesley']) / Label: 0
# Input: [3489, 17612] (['worm', 'whitcomb']) / Label: 0
# Input: [6614, 12952] (['travels', 'ricksen']) / Label: 0
# Input: [2, 4287] (['the', 'count']) / Label: 0
# Input: [10, 30207] (['that', 'northumberland']) / Label: 0
# Input: [231, 6587] (['users', 'maurice']) / Label: 0
# Input: [25, 9483] (['are', "anderson's"]) / Label: 0
# Input: [17, 2666] (['with', 'patients']) / Label: 0
# Input: [9962, 22262] (['poses', 'personalized']) / Label: 0
# Input: [6, 10615] (['a', "aviator's"]) / Label: 0
# Input: [10, 12006] (['that', 'higgins']) / Label: 0
# Input: [25, 31597] (['are', 'kai']) / Label: 0
# Input: [4729, 25503] (['install', 'mugged']) / Label: 0
# Input: [912, 9148] (['windows', 'mains']) / Label: 0
# Input: [9962, 17126] (['poses', 'pavement']) / Label: 0
# Input: [528, 8507] (['warned', 'yoran']) / Label: 0
# Input: [17, 14302] (['with', 'pinnacle']) / Label: 0
# Input: [9961, 22504] (['tetris', 'bolted']) / Label: 0
# Input: [661, 20699] (['virus', 'abstract']) / Label: 0
# Input: [2, 25745] (['the', "speaker's"]) / Label: 0
# Input: [9963, 30463] (['cellery', "morientes'"]) / Label: 0
# Input: [97, 9941] (['game', 'knockout']) / Label: 0
# Input: [51, 29935] (['about', 'ntv']) / Label: 0
# Input: [661, 20616] (['virus', 'fizzy']) / Label: 0
# Input: [9961, 9631] (['tetris', 'desert']) / Label: 0
# Input: [2, 20098] (['the', "carroll's"]) / Label: 0
# Input: [912, 1285] (['windows', 'massive']) / Label: 0
# Input: [231, 6426] (['users', 'seller']) / Label: 0
# Input: [636, 26507] (['popular', 'starbucks']) / Label: 0
# Input: [636, 23636] (['popular', "mumbai's"]) / Label: 0
# Input: [528, 31750] (['warned', 'schoolboy']) / Label: 0
# Input: [3489, 19958] (['worm', 'silvestre']) / Label: 0
# Input: [18, 21554] (['as', 'vacations']) / Label: 0
# Input: [9961, 18058] (['tetris', 'flops']) / Label: 0
# Input: [3489, 13812] (['worm', 'armour']) / Label: 0
# Input: [6614, 28519] (['travels', 'gosaibi']) / Label: 0
# Input: [9963, 6141] (['cellery', 'tear']) / Label: 0
# Input: [912, 32261] (['windows', 'epitestosterone']) / Label: 0
# Input: [51, 12901] (['about', 'ludovico']) / Label: 0
# Input: [87, 19351] (['being', 'scramble']) / Label: 0
# Input: [97, 15386] (['game', 'despairing']) / Label: 0
# Input: [18, 31575] (['as', 'stray']) / Label: 0
# Input: [2090, 24407] (['hugely', 'aramaic']) / Label: 0
# Input: [9961, 9621] (['tetris', 'weitz']) / Label: 0
# Input: [3489, 25459] (['worm', 'leftwing']) / Label: 0
# Input: [6, 22642] (['a', 'hoarding']) / Label: 0
# Input: [2, 31953] (['the', 'fleming']) / Label: 0
# Input: [2090, 32300] (['hugely', 'phalanx']) / Label: 0
# Input: [87, 4344] (['being', 'pact']) / Label: 0
# Input: [3489, 13640] (['worm', 'drill']) / Label: 0
# Input: [6614, 5190] (['travels', '84']) / Label: 0
# Input: [2, 10323] (['the', 'ins']) / Label: 0
# Input: [10, 5347] (['that', 'integral']) / Label: 0
# Input: [231, 23538] (['users', 'agatha']) / Label: 0
# Input: [25, 17546] (['are', "malfunction'"]) / Label: 0
# Input: [17, 7988] (['with', 'tally']) / Label: 0
# Input: [9962, 15715] (['poses', 'mcfarlane']) / Label: 0
# Input: [6, 3029] (['a', 'detained']) / Label: 0
# Input: [10, 4430] (['that', 'ring']) / Label: 0
# Input: [25, 10159] (['are', 'bloggies']) / Label: 0
# Input: [4729, 28287] (['install', 'â£600m']) / Label: 0
# Input: [912, 28522] (['windows', "'idle'"]) / Label: 0
# Input: [9962, 19535] (['poses', 'niebaum']) / Label: 0
# Input: [528, 10476] (['warned', 'designated']) / Label: 0
# Input: [17, 30176] (['with', 'sputter']) / Label: 0
# Input: [9961, 2982] (['tetris', 'anywhere']) / Label: 0
# Input: [661, 26438] (['virus', 'emergencies']) / Label: 0
# Input: [2, 9244] (['the', 'aka']) / Label: 0
# Input: [9963, 18817] (['cellery', 'mcfadyen']) / Label: 0
# Input: [97, 30912] (['game', "wru's"]) / Label: 0
# Input: [51, 7862] (['about', 'gender']) / Label: 0
# Input: [661, 15542] (['virus', 'alli']) / Label: 0
# Input: [9961, 20756] (['tetris', 'bypass']) / Label: 0
# Input: [2, 29995] (['the', 'matchday']) / Label: 0
# Input: [912, 8416] (['windows', 'nots']) / Label: 0
# Input: [231, 473] (['users', 'performance']) / Label: 0
# Input: [636, 8035] (['popular', 'objective']) / Label: 0
# Input: [636, 8134] (['popular', "ferguson's"]) / Label: 0
# Input: [528, 11040] (['warned', "boeing's"]) / Label: 0
# Input: [3489, 4840] (['worm', 'investigations']) / Label: 0
# Input: [18, 14792] (['as', 'mscps']) / Label: 0
# Input: [9961, 12052] (['tetris', 'ziyi']) / Label: 0
# Input: [3489, 29057] (['worm', 'â£234m']) / Label: 0
# Input: [6614, 19094] (['travels', 'arrivals']) / Label: 0
# Input: [9963, 16506] (['cellery', 'jogging']) / Label: 0
# Input: [912, 29268] (['windows', 'meiland']) / Label: 0
# Input: [51, 14479] (['about', 'wikid']) / Label: 0
# Input: [87, 20342] (['being', 'okocha']) / Label: 0
# Input: [97, 10246] (['game', 'webroot']) / Label: 0
# Input: [18, 26389] (['as', 'prevaricated']) / Label: 0
# Input: [2090, 12235] (['hugely', 'apprentice']) / Label: 0
# Input: [9961, 21144] (['tetris', 'relasing']) / Label: 0
# Input: [3489, 31197] (['worm', 'rankles']) / Label: 0
# Input: [6, 14148] (['a', 'â£48']) / Label: 0
# Input: [2, 29715] (['the', 'citu']) / Label: 0
# Input: [2090, 24729] (['hugely', 'cleese']) / Label: 0
# Input: [87, 22388] (['being', 'epson']) / Label: 0
# Input: [3489, 16981] (['worm', 'buses']) / Label: 0
# Input: [6614, 4880] (['travels', 'kostas']) / Label: 0
# Input: [2, 164] (['the', 'see']) / Label: 0
# Input: [10, 24720] (['that', 'cancels']) / Label: 0
# Input: [231, 12502] (['users', 'hinckley']) / Label: 0
# Input: [25, 24761] (['are', 'rnb']) / Label: 0
# Input: [17, 28469] (['with', "lilly's"]) / Label: 0
# Input: [9962, 29779] (['poses', 'iog']) / Label: 0
# Input: [6, 15922] (['a', 'leaped']) / Label: 0
# Input: [10, 29030] (['that', 'questionsmarks']) / Label: 0
# Input: [25, 16315] (['are', 'â£44']) / Label: 0
# Input: [4729, 8263] (['install', 'playable']) / Label: 0
# Input: [912, 14172] (['windows', "d'souza"]) / Label: 0
# Input: [9962, 14374] (['poses', 'cates']) / Label: 0
# Input: [528, 17866] (['warned', 'estefan']) / Label: 0
# Input: [17, 2251] (['with', 'peace']) / Label: 0
# Input: [9961, 21558] (['tetris', "advertiser's"]) / Label: 0
# Input: [661, 25645] (['virus', 'hendry']) / Label: 0
# Input: [2, 21137] (['the', 'ogres']) / Label: 0
# Input: [9963, 13546] (['cellery', 'nomad']) / Label: 0
# Input: [97, 28099] (['game', 'claes']) / Label: 0
# Input: [51, 29567] (['about', 'parul']) / Label: 0
# Input: [661, 6227] (['virus', 'delaigue']) / Label: 0
# Input: [9961, 31970] (['tetris', 'oakley']) / Label: 0
# Input: [2, 2180] (['the', 'delighted']) / Label: 0
# Input: [912, 8529] (['windows', 'selecting']) / Label: 0
# Input: [231, 31101] (['users', 'bromwich']) / Label: 0
# Input: [636, 2445] (['popular', 'essential']) / Label: 0
# Input: [636, 20742] (['popular', 'entitlement']) / Label: 0
# Input: [528, 5351] (['warned', 'crimes']) / Label: 0
# Input: [3489, 26492] (['worm', "'melons'"]) / Label: 0
# Input: [18, 27974] (['as', '815']) / Label: 0
# Input: [9961, 19716] (['tetris', 'anheuser']) / Label: 0
# Input: [3489, 4496] (['worm', 'clay']) / Label: 0
# Input: [6614, 10814] (['travels', 'aspiration']) / Label: 0
# Input: [9963, 27091] (['cellery', 'courageous']) / Label: 0
# Input: [912, 31325] (['windows', "courses'"]) / Label: 0

# %%
batch_size = 4096 # Data points in a single batch

embedding_size = 128 # Dimension of the embedding vector.

window_size=1 # We use a window size of 1 on either side of target word
epochs = 5 # Number of epochs to train for
negative_samples = 4 # Number of negative samples generated per example

# We pick a random validation set to sample nearest neighbors
valid_size = 16 # Random set of words to evaluate similarity on.
# We sample valid datapoints randomly from a large window without always being deterministic
valid_window = 250

# When selecting valid examples, we select some of the most frequent words as well as
# some moderately rare words as well
np.random.seed(54321)
random.seed(54321)

valid_term_ids = np.array(random.sample(range(valid_window), valid_size))
valid_term_ids = np.append(
    valid_term_ids, random.sample(range(1000, 1000+valid_window), valid_size),
    axis=0
)

# %%
import tensorflow.keras.backend as K

K.clear_session()


# Inputs; target input layer will have the final shape [None]
# context will have [None, 2xwindow_size] shape
input_1 = tf.keras.layers.Input(shape=())
input_2 = tf.keras.layers.Input(shape=(window_size*2,))

# Target and context embedding layers
target_embedding_layer = tf.keras.layers.Embedding(
    input_dim=n_vocab+1, output_dim=embedding_size, name='target_embedding'
)

context_embedding_layer = tf.keras.layers.Embedding(
    input_dim=n_vocab+1, output_dim=embedding_size, name='context_embedding'
)

# Outputs of the target and context embedding lookups
context_out = context_embedding_layer(input_2)
target_out = target_embedding_layer(input_1)

# Taking the mean over the all the context words to produce [None, embedding_size]
mean_context_out = tf.keras.layers.Lambda(lambda x: tf.reduce_mean(x, axis=1))(context_out)

# Computing the dot product between the two 
out = tf.keras.layers.Dot(axes=-1)([context_out, target_out])

cbow_model = tf.keras.models.Model(inputs=[input_1, input_2], outputs=out, name='cbow_model')

cbow_model.compile(
    loss=tf.keras.losses.BinaryCrossentropy(from_logits=True), 
    optimizer='adam', 
    metrics=['accuracy']
)

cbow_model.summary()
# Out:
# Model: "cbow_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 2)]          0
# __________________________________________________________________________________________________
# context_embedding (Embedding)   (None, 2, 128)       4142336     input_2[0][0]
# __________________________________________________________________________________________________
# input_1 (InputLayer)            [(None,)]            0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 128)          0           context_embedding[0][0]
# __________________________________________________________________________________________________
# target_embedding (Embedding)    (None, 128)          4142336     input_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1)            0           lambda[0][0]
#                                                                  target_embedding[0][0]
# ==================================================================================================
# Total params: 8,284,672
# Trainable params: 8,284,672
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def cbow_data_generator(sequences, window_size, batch_size, negative_samples):
    
    rand_sequence_ids = np.arange(len(sequences))                    
    np.random.shuffle(rand_sequence_ids)

    for si in rand_sequence_ids:
        inputs, labels = cbow_grams(
            sequences[si], 
            vocabulary_size=len(tokenizer.word_index.items())+1, 
            window_size=window_size, 
            negative_samples=negative_samples, 
            shuffle=True,
            sampling_table=sampling_table,
            seed=None
        )
        
        inputs_context, inputs_target, labels = np.array([inp[1] for inp in inputs]), np.array([inp[0] for inp in inputs]), np.array(labels).reshape(-1,1)        
        #print(inputs_context.shape, inputs_target.shape, labels.shape)
        for eg_id_start in range(0, inputs_context.shape[0], batch_size):            
            
            yield (
                inputs_target[eg_id_start: min(eg_id_start+batch_size, inputs_context.shape[0])], 
                inputs_context[eg_id_start: min(eg_id_start+batch_size, inputs_target.shape[0]),:]
            ), labels[eg_id_start: min(eg_id_start+batch_size, labels.shape[0])]

# %%
cbow_validation_callback = ValidationCallback(valid_term_ids, cbow_model, tokenizer)

for ei in range(epochs):
    print("Epoch: {}/{} started".format(ei+1, epochs))
    news_cbow_gen = cbow_data_generator(news_sequences, window_size, batch_size, negative_samples)
    cbow_model.fit(
        news_cbow_gen, 
        epochs=1, 
        callbacks=cbow_validation_callback,         
    )

os.makedirs('cbow_embeddings', exist_ok=True)

np.save(
    os.path.join("cbow_embeddings", "context_embeddings.npy"), 
    cbow_model.get_layer("context_embedding").get_weights()[0]
)
np.save(
    os.path.join("cbow_embeddings", "target_embeddings.npy"), 
    cbow_model.get_layer("target_embedding").get_weights()[0]
)
# Out:
# Epoch: 1/5 ended
# 2226/2226 [==============================] - 92s 41ms/step - loss: 0.5245 - accuracy: 0.7993
# election: union, recognised, owned, each, mechanical
# months: cicero, every, world's, too, revised
# with: by, including, since, japanese, women's
# you: we, they, can, not, now
# were: onto, by, or, but, against
# win: theme, lost, accounting, earlier, reached
# those: star, singer, 5m, survey, robert
# music: actress, according, including, 4m, while
# also: has, claimed, must, already, who
# around: morgan, singer, euros, 5m, before
# best: actress, m, 5m, singer, s
# him: singer, east, alan, energy, towards
# too: 5m, shares, joe, network, prince
# into: including, after, singer, prince, via
# through: include, star, 5m, faces, before
# mr: wearing, park, easily, gordon, michael
# leave: thomas, site, instead, giant, ben
# 5bn: singer, 5m, standing, whose, actress
# met: self, actress, crystal, theft, 14
# believed: veteran, distance, satellite, east, according
# debut: 5m, singer, self, gareth, helped
# images: park, against, shares, bt's, robert
# sound: private, euros, according, singer, through
# champions: official, actress, compulsory, payment, standing
# individual: whose, star, paul, women's, s
# businesses: nadal, accounting, cause, mental, star
# deutsche: euros, singer, among, 70, around
# especially: actress, face, star, another, non
# machine: tv, starring, rugby, its, star
# files: debut, singer, faces, s, wilkinson
# positive: children's, size, steve, maker, lord
# pop: star, family, before, 5m, whose
#
#
# Epoch: 2/5 ended
# 2225/2225 [==============================] - 92s 41ms/step - loss: 0.3999 - accuracy: 0.8071
# election: attorney, motors, each, workers', merchandise
# months: weeks, second, february, detention, whole
# with: between, japanese, cancel, winger, medicines
# you: we, they, people, not, i
# were: are, if, when, but, being
# win: paul, clearly, campbell, complex, knapman
# those: radcliffe, queen's, unfair, wonder, egyptian
# music: sister, stern, host, upper, prosecutor
# also: now, they, already, simply, never
# around: â£4, reached, cole, jackson's, morgan
# best: aviator, performance, dimitri, actress, sideways
# him: them, posters, wolves, maintained, helped
# too: very, so, collections, really, incredibly
# into: fresh, via, seriously, detailed, beaten
# through: cole, sprinter, lse, weighed, environmental
# mr: tony, gordon, michael, charles, jack
# leave: upward, 74, jennifer, internal, potentially
# 5bn: 5m, 8m, 4m, standing, findings
# met: lengthy, 13, reading, 41, 19bn
# believed: was, reject, had, have, might
# debut: gross, arsenal's, draft, agent, santoro
# images: park, edge, post, behaviour, jim
# sound: cole, wasn't, ill, specially, effectively
# champions: premier, champion, actress, rugby, midfielder
# individual: ronaldo, aged, transactions, potentially, mills
# businesses: accounting, warm, 7m, nadal, findings
# deutsche: radcliffe, motor, presenter, thion, secret
# especially: beating, arsenal's, australia's, resorts, nigerian
# machine: ambani, nominee, jennifer, resorts, kimberly
# files: reynolds, mills, potentially, 45, sun
# positive: justin, fought, frontman, mainly, remained
# pop: scores, jenkins, orlando, arsenal's, aka
#
#
# Epoch: 3/5 ended
# 2226/2226 [==============================] - 92s 41ms/step - loss: 0.3607 - accuracy: 0.8232
# election: motors, attorney, merchandise, upcoming, meeting
# months: weeks, years, days, month, times
# with: between, accession, dotted, snatched, own
# you: we, they, don't, i, not
# were: are, if, had, have, was
# win: campbell, draw, rangers, dan, targets
# those: equivalent, tunnel, radcliffe, formally, equally
# music: terrestrial, children's, government's, cockbain, academy
# also: already, now, never, previously, actually
# around: accept, sustaining, you're, paying, denying
# best: actress, supporting, sideways, b, album
# him: them, themselves, helped, me, won't
# too: very, really, so, extremely, pretty
# into: upon, after, towards, rigging, through
# through: poorly, sparks, offset, likhovtseva, unreleased
# mr: tony, gordon, charles, michael, jack
# leave: aka, gamer, resorts, disappointment, anastacia
# 5bn: 4bn, 5m, 2bn, 7bn, 1bn
# met: delivered, carlo, agreed, ran, push
# believed: insisted, when, say, feel, did
# debut: indoor, indian, series, album, oscars
# images: edge, expert, 2's, olivier, collective
# sound: always, simply, probably, cole, wasn't
# champions: premier, rugby, midfielder, ladder, actress
# individual: birthday, responded, greening, dog, universal
# businesses: orquera, stores, garcia, 7m, statements
# deutsche: rachel, incapacitated, mortgage, raf, lied
# especially: poor, beating, settled, club's, freeze
# machine: watson, scores, presley, resorts, prefer
# files: sporting, dubs', foster, habit, oxfam
# positive: territory, ec, blasts, feeling, henry's
# pop: compile, aka, gallery, panasonic, veteran
#
#
# Epoch: 4/5 ended
# 2226/2226 [==============================] - 92s 41ms/step - loss: 0.3279 - accuracy: 0.8407
# election: attorney, motors, workers', merchandise, meeting
# months: years, days, weeks, times, minutes
# with: constructive, solved, between, dotted, ankle
# you: we, they, don't, we'll, i
# were: are, have, know, we're, insist
# win: lead, save, return, receive, hold
# those: benefited, formally, woman, access, avoided
# music: terrestrial, casual, cameras, financial, camera
# also: already, now, never, always, previously
# around: sustaining, upon, biometric, 84, overtake
# best: supporting, actress, category, tennis, american
# him: them, themselves, me, anything, polling
# too: very, so, relatively, extremely, pretty
# into: after, upon, under, through, ahead
# through: off, bankrupt, caught, knowing, upon
# mr: tony, gordon, resignation, cherie, charles
# leave: 162, attending, sang, barber, sporting
# 5bn: 5m, 8bn, 2bn, 7bn, 4bn
# met: agreed, failed, mick, seifert, carlos
# believed: knew, saying, lets, suggest, insist
# debut: indoor, album, series, saints', women's
# images: sebastien, anderson, serbia, aguilera, roadside
# sound: cole, recognise, confess, secretly, getting
# champions: premier, rugby, irish, football, midfielder
# individual: greening, profound, enables, professionals, palestinian
# businesses: orquera, volley, numbers, medium, statements
# deutsche: austria, austria's, lyon, violence, incapacitated
# especially: estate, weapon, eu's, presentations, palestinian
# machine: ambani, hoddle, watson, 028, adjustment
# files: vast, resorts, individual, unfair, donald
# positive: britannia, territory, difficulties, animation, undertaking
# pop: veteran, compile, joel, holds, fiction
#
#
# Epoch: 5/5 ended
# 2226/2226 [==============================] - 92s 41ms/step - loss: 0.3009 - accuracy: 0.8562
# election: attorney, motors, workers', release, meeting
# months: years, days, weeks, minutes, seasons
# with: constructive, between, solved, reservoir, dotted
# you: we, they, i, don't, we'll
# were: are, aren't, have, because, need
# win: hain, lead, replacing, receive, hold
# those: wrongly, popular, equivalent, affluent, woman
# music: terrestrial, cameras, casual, divide, camera
# also: already, previously, recently, rarely, reportedly
# around: surveyed, accept, primarily, overtake, sustaining
# best: supporting, actress, category, fiction, contenders
# him: them, me, themselves, won't, censors
# too: very, so, relatively, extremely, incredibly
# into: after, rigging, upon, longest, howl's
# through: bankrupt, strongly, queried, suicide, poorly
# mr: tony, gordon, resignation, cherie, jack
# leave: pakistan, 162, miss, enhance, heaped
# 5bn: 5m, 7bn, 4bn, 8bn, 8m
# met: announced, revealed, seifert, warned, insisted
# believed: did, knew, does, knows, believe
# debut: indoor, successive, saints', album, boxer
# images: anderson, banks, sex, websites, promoter
# sound: confess, felony, deny, manually, revolutionised
# champions: premier, rugby, appearances, irish, midfielder
# individual: transmit, combines, state's, random, preserve
# businesses: charges, recall, volley, medium, mapping
# deutsche: austria, austria's, butcher, violence, 1989
# especially: weapon, poor, eu's, discrimination, dubious
# machine: cullen, thereby, ras, examination, debuted
# files: movies, collections, vast, habit, ballad
# positive: deployment, territory, drinkers, caring, nationals
# pop: fiction, veteran, scrubs, wars, commonwealth

# %% [markdown]
# ## Visulizing the Learnings of the Skip-Gram Algorithm

# %% [markdown]
# ### Finding Only the Words Clustered Together Instead of Sparsely Distributed Words

# %%
def find_clustered_embeddings(embeddings,distance_threshold,sample_threshold):
    ''' 
    Find only the closely clustered embeddings. 
    This gets rid of more sparsly distributed word embeddings and make the visualization clearer
    This is useful for t-SNE visualization
    
    distance_threshold: maximum distance between two points to qualify as neighbors
    sample_threshold: number of neighbors required to be considered a cluster
    '''
    
    # calculate cosine similarity
    cosine_sim = np.dot(embeddings,np.transpose(embeddings))
    norm = np.dot(np.sum(embeddings**2,axis=1).reshape(-1,1),np.sum(np.transpose(embeddings)**2,axis=0).reshape(1,-1))
    assert cosine_sim.shape == norm.shape
    cosine_sim /= norm
    
    # make all the diagonal entries zero otherwise this will be picked as highest
    np.fill_diagonal(cosine_sim, -1.0)
    
    argmax_cos_sim = np.argmax(cosine_sim, axis=1)
    mod_cos_sim = cosine_sim
    # find the maximums in a loop to count if there are more than n items above threshold
    for _ in range(sample_threshold-1):
        argmax_cos_sim = np.argmax(cosine_sim, axis=1)
        mod_cos_sim[np.arange(mod_cos_sim.shape[0]),argmax_cos_sim] = -1
    
    max_cosine_sim = np.max(mod_cos_sim,axis=1)

    return np.where(max_cosine_sim>distance_threshold)[0]

# %% [markdown]
# ### Computing the t-SNE Visualization of Word Embeddings Using Scikit-Learn

# %%
import sklearn

num_points = 10000 # we will use a large sample space to build the T-SNE manifold and then prune it using cosine similarity

rand_ids = np.random.randint(1, num_points, size=(350,))

tsne = TSNE(
    perplexity=30, n_components=2, n_iter=5000, metric='cosine')

print('Fitting embeddings to T-SNE. This can take some time ...')
# get the T-SNE manifold
selected_embeddings = skip_gram_model.get_layer("context_embedding").get_weights()[0][rand_ids, :]
print(selected_embeddings.shape)
two_d_embeddings = tsne.fit_transform(selected_embeddings)

print('Pruning the T-SNE embeddings')
# prune the embeddings by getting ones only more than n-many sample above the similarity threshold
# this unclutters the visualization
#selected_ids = find_clustered_embeddings(selected_embeddings,.25,10)
#two_d_embeddings = two_d_embeddings[selected_ids,:]

#print('Out of ',num_points,' samples, ', selected_ids.shape[0],' samples were selected by pruning')
print('\tDone')
# Out:
# Fitting embeddings to T-SNE. This can take some time ...
# (350, 128)
# Pruning the T-SNE embeddings
# 	Done

# %% [markdown]
# ### Plotting the t-SNE Results with Matplotlib

# %%
def plot(embeddings, labels):
  
  n_clusters = 20 # number of clusters
  # automatically build a discrete set of colors, each for cluster
  #label_colors = [pylab.cm.spectral(float(i) /n_clusters) for i in range(n_clusters)]
  
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  
  # Define K-Means
  #kmeans = KMeans(n_clusters=n_clusters, init='k-means++', random_state=0).fit(embeddings)
  #kmeans_labels = kmeans.labels_
  
  pylab.figure(figsize=(15,15))  # in inches
    
  # plot all the embeddings and their corresponding words
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)#, c=label_colors[klabel])    
        
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom',fontsize=10)

  # use for saving the figure if needed
  #pylab.savefig('word_embeddings.png')
  pylab.show()

words = [tokenizer.index_word[i] for i in rand_ids]
plot(two_d_embeddings, words)
